# %%
# EJERCICIO 3
import requests

# Llamado a una API pública
url = "https://jsonplaceholder.typicode.com/users"
response = requests.get(url)
usuarios = response.json()

# Procesamiento imperativo
nombres = []
for u in usuarios:
    nombres.append(u["name"])

print("Usuarios encontrados:")
for n in nombres:
    print("-", n)

# Filtrar solo los usuarios cuyo correo termine en .biz
print("Usuarios con correo que termina en .biz")
usuarios_biz = []
for u in usuarios:
    if u["email"].endswith(".biz"):
        usuarios_biz.append(u)

# Mostrar nombre de estos usuarios
for u in usuarios_biz:
    print(f"- {u['name']}: {u['email']}")


#2
import requests
# Entrada de datos
nombre_pokemon = input("Ingrese el nombre de un Pokémon: ").lower()
# Llamado a la API
url = f"https://pokeapi.co/api/v2/pokemon/{nombre_pokemon}"
respuesta = requests.get(url)
# Verificación del estado de la respuesta
if respuesta.status_code == 200:
    datos = respuesta.json()

    # Modelado del estado del Pokémon
    pokemon = {
        "nombre": datos["name"],
        "altura": datos["height"],
        "peso": datos["weight"],
        "tipos": [t["type"]["name"] for t in datos["types"]],
        "habilidades": [h["ability"]["name"] for h in datos["abilities"]],
        "stats": {s["stat"]["name"]: s["base_stat"] for s in datos["stats"]},
        "experiencia_base": datos["base_experience"]
    }

    # Salida del estado actual
    print("\n Información del Pokémon")
    print(f"Nombre: {pokemon['nombre'].capitalize()}")
    print(f"Altura: {pokemon['altura']} decímetros")
    print(f"Peso: {pokemon['peso']} hectogramos")
    print(f"Tipos: {', '.join(pokemon['tipos'])}")

    # Condicionales adicionales
    if len(pokemon['tipos']) > 1:
        print("Pokémon de tipo mixto")
    else:
        print("Pokémon de tipo único")

    if pokemon['peso'] > 100:
        print("Pokémon de gran tamaño")
    else:
        print("Pokémon ligero")

    # Mostrar habilidades una por una con for
    print("\n Habilidades:")
    for habilidad in pokemon['habilidades']:
        print(f"  - {habilidad.capitalize()}")

    # Añadido interesante: mostrar estadísticas base
    print("\n Estadísticas base:")
    for stat_name, stat_value in pokemon['stats'].items():
        print(f"  {stat_name.replace('-', ' ').title()}: {stat_value}")

    # Añadido interesante: experiencia base
    if pokemon['experiencia_base'] > 200:
        print(f"\n Pokémon con alta experiencia base: {pokemon['experiencia_base']}")
    elif pokemon['experiencia_base'] > 0:
        print(f"\n Experiencia base: {pokemon['experiencia_base']}")

    # Añadido interesante: sugerencia según altura
    if pokemon['altura'] < 5:
        print(" Pokémon pequeño en tamaño")
    elif pokemon['altura'] < 15:
        print("Pokémon de tamaño mediano")
    else:
        print("Pokémon gigante")

else:
    print("Pokémon no encontrado. Verifique el nombre ingresado.")
# Out:
# Usuarios encontrados:
# - Leanne Graham
# - Ervin Howell
# - Clementine Bauch
# - Patricia Lebsack
# - Chelsey Dietrich
# - Mrs. Dennis Schulist
# - Kurtis Weissnat
# - Nicholas Runolfsdottir V
# - Glenna Reichert
# - Clementina DuBuque
# Usuarios con correo que termina en .biz
# - Leanne Graham: Sincere@april.biz
# - Kurtis Weissnat: Telly.Hoeger@billy.biz
# - Clementina DuBuque: Rey.Padberg@karina.biz
# Ingrese el nombre de un Pokémon: pikachu
#
#  Información del Pokémon
# Nombre: Pikachu
# Altura: 4 decímetros
# Peso: 60 hectogramos
# Tipos: electric
# Pokémon de tipo único
# Pokémon ligero
#
#  Habilidades:
#   - Static
#   - Lightning-rod
#
#  Estadísticas base:
#   Hp: 35
#   Attack: 55
#   Defense: 40
#   Special Attack: 50
#   Special Defense: 50
#   Speed: 90
#
#  Experiencia base: 112
#  Pokémon pequeño en tamaño
